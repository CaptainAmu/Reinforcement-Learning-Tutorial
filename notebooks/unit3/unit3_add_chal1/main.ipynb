# %% [markdown]
# <a href="https://colab.research.google.com/github/CaptainAmu/Reinforcement-Learning-Tutorial/blob/main/notebooks/unit3/unit3_add_chal1/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Run ONLY ONCE at each session start ##

# %%
# !git clone https://github.com/CaptainAmu/Reinforcement-Learning-Tutorial.git
# Out:
# Cloning into 'Reinforcement-Learning-Tutorial'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 189 (delta 43), reused 61 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (189/189), 30.51 MiB | 27.82 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %% [markdown]
# ### Go to directory and start working

# %%
# !pwd
# %cd /content/Reinforcement-Learning-Tutorial/
# Out:
# /content
# /content/Reinforcement-Learning-Tutorial

# %%
from google.colab import userdata
gt = userdata.get('GITHUB_TOKEN')

# !git remote set-url origin https://CaptainAmu:{gt}@github.com/CaptainAmu/Reinforcement-Learning-Tutorial.git
# !git config --global user.email 'lsc1885@gmail.com'
# !git config --global user.name 'ShuchengLi'

# %%
def git_save(commit_message):
  # !git add .
  # !git commit -m "{commit_message}"
  # !git push

# %% [markdown]
# ---

# %%
# %cd /content/Reinforcement-Learning-Tutorial/notebooks/unit3/unit3_add_chal1
# Out:
# /content/Reinforcement-Learning-Tutorial/notebooks/unit3/unit3_add_chal1

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-wf20t4w7
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-wf20t4w7
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit ab4aadb57c6c42abcf1016318c2bebe35c4c1270
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.7.0 (from rl_zoo3==2.7.0)
#   Downloading sb3_contrib-2.7.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.7.0) (1.2.0)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.7.0)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.7.0) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.7.0) (13.9.4)
# Collecting optuna>=3.0 (from rl_zoo3==2.7.0)
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.7.0) (6.0.2)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.7.0)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.7.0)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (0.34.4)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (1.1.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.7.0) (1.16.5)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.7.0)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.7.0) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.7.0) (2.0.43)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.12/dist-packages (from pytablewriter~=1.2->rl_zoo3==2.7.0) (75.2.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting stable_baselines3<3.0,>=2.7.0 (from sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->rl_zoo3==2.7.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->rl_zoo3==2.7.0) (2.19.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.7.0) (1.3.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (1.1.9)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.7.0) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.7.0) (5.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.7.0) (3.2.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2.8.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.7.0) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.2.3)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.3.0)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 10.8 MB/s eta 0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 7.2 MB/s eta 0:00:00
# Downloading sb3_contrib-2.7.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 7.1 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 13.8 MB/s eta 0:00:00
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.7.0-py3-none-any.whl size=78020 sha256=b1e62462d9d9cb404e0a4c76c9d90220ce22742d13640aaa483ae7843d343db2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g9js3uxs/wheels/cd/09/5b/8130538724a187021e02afe53ce7a1269c516a78a487a1ba15
# Successfully built rl_zoo3
# Installing collected packages: tcolorpy, pathvalidate, mbstrdecoder, colorlog, typepy, shimmy, optuna, huggingface_sb3, stable_baselines3, DataProperty, tabledata, sb3_contrib, pytablewriter, rl_zoo3
# Successfully installed DataProperty-1.1.0 colorlog-6.9.0 huggingface_sb3-3.0 mbstrdecoder-1.1.4 optuna-4.5.0 pathvalidate-3.3.1 pytablewriter-1.2.1 rl_zoo3-2.7.0 sb3_contrib-2.7.0 shimmy-2.0.0 stable_baselines3-2.7.0 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 35 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 0s (3,410 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 126374 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install "gymnasium[atari,accept-rom-license]"
# !pip install autorom[accept-rom-license]
# !AutoROM --accept-license
# Out:
# Requirement already satisfied: gymnasium[accept-rom-license,atari] in /usr/local/lib/python3.12/dist-packages (1.2.0)
# WARNING: gymnasium 1.2.0 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (0.11.2)
# Collecting autorom[accept-rom-license]
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (8.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (2.32.4)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 6.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2025.8.3)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446709 sha256=4e4b1c9299717e3780bf2f0ac67c3eee5942ac3fc8b74da587a0f59dddba4d33
#   Stored in directory: /root/.cache/pip/wheels/99/f1/ff/c6966c034a8259164bdc9deb4d1ea839f119474638100e6645
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.6.1
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
#
# Existing ROMs will be overwritten.

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ### Training an agent to play PongNoFrameskip-v4 from scratch

# %%
# !python -m rl_zoo3.train --algo dqn --env PongNoFrameskip-v4 -f rl_from_scratch/ -c dqn.yml
# Out:
# 2025-09-16 03:56:56.457956: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757995016.496742    3564 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757995016.509263    3564 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757995016.539798    3564 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757995016.539858    3564 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757995016.539863    3564 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757995016.539866    3564 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-16 03:56:56.549284: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ========== PongNoFrameskip-v4 ==========
# Seed: 1359680831
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cpu device
# Log path: rl_from_scratch//dqn/PongNoFrameskip-v4_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 500      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 541      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 7162     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 526      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 10886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 534      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 14767    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 538      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 18347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 549      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 21908    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=-20.40 +/- 0.80
# Episode length: 3494.60 +/- 272.02
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.49e+03 |
# |    mean_reward      | -20.4    |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 449      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 25680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 468      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 29526    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 475      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 32962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 488      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 36577    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 493      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 40545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 501      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 44144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 504      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 47830    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=-20.80 +/- 0.40
# Episode length: 3412.20 +/- 192.09
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.41e+03 |
# |    mean_reward      | -20.8    |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.491    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 456      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 51419    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 461      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 55209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.418    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 470      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 58824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 474      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 62713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.347    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 476      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 65993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.31     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 479      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 69742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.273    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 485      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 73393    |
# ----------------------------------
# Saving to rl_from_scratch//dqn/PongNoFrameskip-v4_2
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.12/dist-packages/rl_zoo3/train.py", line 286, in <module>
#     train()
#   File "/usr/local/lib/python3.12/dist-packages/rl_zoo3/train.py", line 280, in train
#     exp_manager.save_trained_model(model)
#   File "/usr/local/lib/python3.12/dist-packages/rl_zoo3/exp_manager.py", line 286, in save_trained_model
#     model.save(f"{self.save_path}/{self.env_name}")
#   File "/usr/local/lib/python3.12/dist-packages/stable_baselines3/common/base_class.py", line 838, in save
#     exclude = set(exclude).union(self._excluded_save_params())
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/stable_baselines3/dqn/dqn.py", line 282, in _excluded_save_params
#     return [*super()._excluded_save_params(), "q_net", "q_net_target"]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/stable_baselines3/common/base_class.py", line 303, in _excluded_save_params
#     def _excluded_save_params(self) -> list[str]:
#
# KeyboardInterrupt

# %% [markdown]
# ### Continue Training an already-trained agent playing PongNoFrameskip-v4

# %% [markdown]
# Download the trained model from hub to local.

# %%
# !python -m rl_zoo3.load_from_hub --algo dqn --env PongNoFrameskip-v4 -orga sb3 -f rl_trained
# Out:
# 2025-09-16 04:07:34.118036: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757995654.162595    6141 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757995654.174642    6141 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757995654.207969    6141 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757995654.208029    6141 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757995654.208034    6141 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757995654.208038    6141 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-16 04:07:34.217377: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Downloading from https://huggingface.co/sb3/dqn-PongNoFrameskip-v4
# dqn-PongNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:00<00:00, 108MB/s]
# config.yml: 100% 548/548 [00:00<00:00, 2.80MB/s]
# No normalization file
# args.yml: 100% 882/882 [00:00<00:00, 4.79MB/s]
# env_kwargs.yml: 100% 3.00/3.00 [00:00<00:00, 20.3kB/s]
# train_eval_metrics.zip: 100% 309k/309k [00:00<00:00, 292MB/s]
# Saving to rl_trained/dqn/PongNoFrameskip-v4_2

# %% [markdown]
# Retrain the model (now let's try using ddqn).

# %%
# !python -m rl_zoo3.train --algo dqn --env PongNoFrameskip-v4 -f rl_trained/ -c dqn.yml
# Out:
# 2025-09-16 04:42:45.012619: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757997765.052977   14587 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757997765.065471   14587 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757997765.097375   14587 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757997765.097438   14587 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757997765.097445   14587 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757997765.097449   14587 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-16 04:42:45.106489: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ========== PongNoFrameskip-v4 ==========
# Seed: 3783179909
# Loading hyperparameters from: ddqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 10000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cpu device
# Log path: rl_trained//dqn/PongNoFrameskip-v4_4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.55e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 521      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 3534     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 569      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 7366     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 560      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 11057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 587      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 14792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 593      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 18321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 602      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 22101    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=-20.20 +/- 1.17
# Episode length: 3939.60 +/- 581.13
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.94e+03 |
# |    mean_reward      | -20.2    |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 487      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 25981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 488      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 29558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.67     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 505      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 33324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 512      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 37101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 523      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 40489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 528      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 44274    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 538      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 48072    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=-20.40 +/- 0.49
# Episode length: 3604.60 +/- 439.30
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.6e+03  |
# |    mean_reward      | -20.4    |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.488    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 477      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 51670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 487      |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 55611    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 493      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 59871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.371    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 502      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 63581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 505      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 67250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 511      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 70895    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.262    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 514      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 74531    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=-21.00 +/- 0.00
# Episode length: 3390.20 +/- 361.32
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.39e+03 |
# |    mean_reward      | -21      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.227    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 473      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 78126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.194    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 476      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 81398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 482      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 84999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.121    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 486      |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 88761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.0831   |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 492      |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 92617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.0451   |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 495      |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 96452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.0102   |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 500      |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 99980    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.06e+03 |
# |    mean_reward      | -21      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 100000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 336      |
# |    time_elapsed     | 305      |
# |    total_timesteps  | 103096   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.031    |
# |    n_updates        | 773      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 265      |
# |    time_elapsed     | 399      |
# |    total_timesteps  | 106132   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 1532     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 220      |
# |    time_elapsed     | 494      |
# |    total_timesteps  | 109196   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0302   |
# |    n_updates        | 2298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 186      |
# |    time_elapsed     | 601      |
# |    total_timesteps  | 112430   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 3107     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 165      |
# |    time_elapsed     | 700      |
# |    total_timesteps  | 115620   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00121  |
# |    n_updates        | 3904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 147      |
# |    time_elapsed     | 807      |
# |    total_timesteps  | 118958   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 4739     |
# ----------------------------------
# Saving to rl_trained//dqn/PongNoFrameskip-v4_4

# %%
# !python -m rl_zoo3.enjoy \
    --algo dqn \
    --env PongNoFrameskip-v4 \
    -n 5000 -f rl_trained/
# Out:
# 2025-09-16 05:02:36.751915: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757998956.791481   19352 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757998956.803816   19352 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757998956.835084   19352 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757998956.835174   19352 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757998956.835180   19352 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757998956.835184   19352 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-16 05:02:36.844288: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=2
# Loading rl_trained/dqn/PongNoFrameskip-v4_2/PongNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: -20.00
# Atari Episode Length 3815
# Atari Episode Score: -21.00
# Atari Episode Length 4166
# Atari Episode Score: -21.00
# Atari Episode Length 4032
# Atari Episode Score: -20.00
# Atari Episode Length 3847
# Atari Episode Score: -21.00
# Atari Episode Length 3776

# %% [markdown]
# Save the model to my hub instead

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !python -m rl_zoo3.push_to_hub --algo dqn --env PongNoFrameskip-v4 --repo-name dqn-PongNoFrameskip-v4 -orga ShuchengLi -f rl_trained/
# Out:
# 2025-09-16 05:13:54.675603: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757999634.699843   22091 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757999634.706932   22091 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757999634.725081   22091 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757999634.725155   22091 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757999634.725164   22091 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757999634.725168   22091 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-16 05:13:54.730703: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=2
# Loading rl_trained/dqn/PongNoFrameskip-v4_2/PongNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to ShuchengLi/dqn-PongNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# .gitattributes: 1.52kB [00:00, 318kB/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00,  4.92it/s]
# Saving model to: hub/dqn-PongNoFrameskip-v4/dqn-PongNoFrameskip-v4
# Saving video to /tmp/tmpgsvrnt_x/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /tmp/tmpgsvrnt_x/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpgsvrnt_x/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpgsvrnt_x/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo dqn-PongNoFrameskip-v4 to the Hugging Face Hub
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
# Processing Files (1 / 1)                :   0% 1.26k/54.2M [00:00<5:12:05, 2.90kB/s, 6.31kB/s  ]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:   1% 202k/13.5M [00:00<?, ?B/s]
#
#
#
#   ...4/dqn-PongNoFrameskip-v4/policy.pth:   1% 202k/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip:   1% 408k/27.2M [00:00<?, ?B/s]
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip:   1% 66.0/4.41k [00:00<?, ?B/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:   1% 202k/13.5M [00:00<?, ?B/s]
#
#
#
#   ...4/dqn-PongNoFrameskip-v4/policy.pth:   1% 202k/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip:   1% 408k/27.2M [00:00<?, ?B/s]
#
#
#
#
#
# Processing Files (1 / 5)                :   2% 814k/54.2M [00:01<00:59, 898kB/s, 1.02MB/s  ]
# New Data Upload                         :   1% 800k/53.4M [00:01<01:08, 772kB/s, 1.00MB/s  ]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  18% 2.43M/13.5M [00:00<00:00, 11.2MB/s]
#
#
#
#   ...4/dqn-PongNoFrameskip-v4/policy.pth:  18% 2.43M/13.5M [00:00<00:00, 11.2MB/s]
#
#
#
#
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip:  18% 4.90M/27.2M [00:00<00:00, 22.5MB/s]
#
#
#
#
#
# Processing Files (1 / 5)                :  18% 9.76M/54.2M [00:01<00:03, 11.4MB/s, 9.76MB/s  ]
# New Data Upload                         :  18% 9.61M/53.4M [00:01<00:04, 10.1MB/s, 9.61MB/s  ]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  75% 10.1M/13.5M [00:00<00:00, 24.7MB/s]
#
#
#
#   ...4/dqn-PongNoFrameskip-v4/policy.pth:  75% 10.1M/13.5M [00:00<00:00, 24.8MB/s]
#
#
#
#
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip:  75% 20.4M/27.2M [00:00<00:00, 49.9MB/s]
#
#
#
#
#
# Processing Files (1 / 5)                :  75% 40.6M/54.2M [00:01<00:00, 47.9MB/s, 33.8MB/s  ]
# New Data Upload                         :  75% 40.0M/53.4M [00:01<00:00, 43.6MB/s, 33.3MB/s  ]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  99% 13.4M/13.5M [00:00<00:00, 21.9MB/s]
#
#
#
#   ...4/dqn-PongNoFrameskip-v4/policy.pth:  99% 13.4M/13.5M [00:00<00:00, 21.9MB/s]
#
#
#
#
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip:  99% 26.9M/27.2M [00:00<00:00, 44.2MB/s]
#
#
#
#
#
# Processing Files (1 / 5)                :  99% 53.6M/54.2M [00:01<00:00, 52.5MB/s, 38.3MB/s  ]
# New Data Upload                         :  99% 52.8M/53.4M [00:01<00:00, 48.8MB/s, 37.7MB/s  ]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  99% 13.4M/13.5M [00:00<00:00, 16.5MB/s]
#
#
#
#   ...4/dqn-PongNoFrameskip-v4/policy.pth:  99% 13.4M/13.5M [00:00<00:00, 16.5MB/s]
#
#
#
#
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip:  99% 26.9M/27.2M [00:00<00:00, 33.2MB/s]
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip:  99% 4.36k/4.41k [00:00<00:00, 5.37kB/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<00:00, 13.3MB/s]
#
#
#
#   ...4/dqn-PongNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<00:00, 13.3MB/s]
#
#
#
#
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:00<00:00, 26.8MB/s]
#
#
#
#
#
# Processing Files (5 / 5)                : 100% 54.2M/54.2M [00:02<00:00, 30.4MB/s, 30.1MB/s  ]
# New Data Upload                         : 100% 53.4M/53.4M [00:02<00:00, 29.0MB/s, 29.7MB/s  ]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<00:00, 11.1MB/s]
#
#
#
#   ...4/dqn-PongNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<00:00, 11.1MB/s]
#
#
#
#
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 22.4MB/s]
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 4.41k/4.41k [00:01<00:00, 3.62kB/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<00:00, 11.0MB/s]
#
#
#
#   ...4/dqn-PongNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<00:00, 11.0MB/s]
#
#
#
#
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 22.2MB/s]
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 4.41k/4.41k [00:01<00:00, 3.59kB/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<00:00, 9.50MB/s]
#
#
#
#   ...4/dqn-PongNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<00:00, 9.51MB/s]
#
#
#
#
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 19.2MB/s]
#
#
#
#
#
# Processing Files (5 / 5)                : 100% 54.2M/54.2M [00:02<00:00, 22.3MB/s, 24.7MB/s  ]
# New Data Upload                         : 100% 53.4M/53.4M [00:02<00:00, 21.9MB/s, 24.3MB/s  ]
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<00:00, 9.50MB/s]
#   ...4/dqn-PongNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<00:00, 9.50MB/s]
#   ...eskip-v4/dqn-PongNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 19.1MB/s]
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 4.41k/4.41k [00:01<00:00, 3.10kB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/ShuchengLi/dqn-PongNoFrameskip-v4

# %%
git_save("Retrained a trained model pulled from baseline3. Pushed result to Huggingface.")
# Out:
# [main dddca08] Retrained a trained model pulled from baseline3. Pushed result to Huggingface.
#  26 files changed, 722 insertions(+), 37 deletions(-)
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/.gitattributes
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/README.md
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/args.yml
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/config.yml
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/dqn-PongNoFrameskip-v4.zip
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/dqn-PongNoFrameskip-v4/_stable_baselines3_version
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/dqn-PongNoFrameskip-v4/data
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/dqn-PongNoFrameskip-v4/policy.optimizer.pth
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/dqn-PongNoFrameskip-v4/policy.pth
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/dqn-PongNoFrameskip-v4/pytorch_variables.pth
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/dqn-PongNoFrameskip-v4/system_info.txt
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/env_kwargs.yml
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/results.json
#  create mode 100644 notebooks/unit3/unit3_add_chal1/hub/dqn-PongNoFrameskip-v4/train_eval_metrics.zip
#  rewrite notebooks/unit3/unit3_add_chal1/rl_from_scratch/dqn/PongNoFrameskip-v4_1/0.monitor.csv (99%)
#  delete mode 100644 notebooks/unit3/unit3_add_chal1/rl_from_scratch/dqn/PongNoFrameskip-v4_1/PongNoFrameskip-v4.zip
#  rewrite notebooks/unit3/unit3_add_chal1/rl_from_scratch/dqn/PongNoFrameskip-v4_1/evaluations.npz (92%)
#  create mode 100644 notebooks/unit3/unit3_add_chal1/rl_trained/dqn/PongNoFrameskip-v4_2/0.monitor.csv
#  create mode 100644 notebooks/unit3/unit3_add_chal1/rl_trained/dqn/PongNoFrameskip-v4_2/PongNoFrameskip-v4.zip
#  create mode 100644 notebooks/unit3/unit3_add_chal1/rl_trained/dqn/PongNoFrameskip-v4_2/PongNoFrameskip-v4/args.yml
#  create mode 100644 notebooks/unit3/unit3_add_chal1/rl_trained/dqn/PongNoFrameskip-v4_2/PongNoFrameskip-v4/command.txt
#  create mode 100644 notebooks/unit3/unit3_add_chal1/rl_trained/dqn/PongNoFrameskip-v4_2/PongNoFrameskip-v4/config.yml
#  create mode 100644 notebooks/unit3/unit3_add_chal1/rl_trained/dqn/PongNoFrameskip-v4_2/best_model.zip
#  create mode 100644 notebooks/unit3/unit3_add_chal1/rl_trained/dqn/PongNoFrameskip-v4_2/evaluations.npz
# Uploading LFS objects: 100% (5/5), 54 MB | 0 B/s, done.
# Enumerating objects: 51, done.
# Counting objects: 100% (51/51), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (33/33), done.
# Writing objects: 100% (39/39), 39.94 MiB | 10.02 MiB/s, done.
# Total 39 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/CaptainAmu/Reinforcement-Learning-Tutorial.git
#    83734f5..dddca08  main -> main
